# %%
import matplotlib.pyplot as plt
import pandas as pd

df_8A100 = pd.read_csv('data_8A100.csv')
print(df_8A100)

df_1V100 = pd.read_csv('data_1V100.csv')
print(df_1V100)

df_4V100 = df_1V100.copy()
df_4V100[df_1V100.columns[1:]] = df_1V100[df_1V100.columns[1:]].apply(lambda x: x * 4)
print(df_4V100)

df_4A100 = df_8A100.copy()
df_4A100[df_8A100.columns[1:]] = df_4A100[df_8A100.columns[1:]].apply(lambda x: x / 2)
print(df_4A100)

Promethion48_TMO = 5,37e-02
Promethion48_keepup = 2,78e-02		
Promethion24_TMO = 2,69e-02
Promethion24_keepup = 1,39e-02
# Out:
#   Basecaller   Fast (Gb/s)  Hac (Gb/s)  sup (Gb/s)
# 0     Dorado         0.130      0.0525     0.00993
# 1      Guppy         0.035      0.0148     0.00561
#   Basecaller   Fast (Gb/s)  Hac (Gb/s)  sup (Gb/s)
# 0     Dorado       0.01180     0.00201    0.000379
# 1      Guppy       0.00796     0.00152    0.000317
#   Basecaller   Fast (Gb/s)  Hac (Gb/s)  sup (Gb/s)
# 0     Dorado       0.04720     0.00804    0.001516
# 1      Guppy       0.03184     0.00608    0.001268
#   Basecaller   Fast (Gb/s)  Hac (Gb/s)  sup (Gb/s)
# 0     Dorado        0.0650     0.02625    0.004965
# 1      Guppy        0.0175     0.00740    0.002805

# %%
import matplotlib.pyplot as plt

# Transposing the DataFrame for easier plotting
df_8A100_T = df_8A100.set_index('Basecaller').T

# Enlarge the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plotting
ax = df_8A100_T.plot(kind='bar', width=0.7, ax=ax)

# Adding horizontal lines for the specified values in different colors
values = {
    'Promethion48_TMO': 5.37e-02,
    'Promethion48_keepup': 2.78e-02,
    'Promethion24_TMO': 2.69e-02,
    'Promethion24_keepup': 1.39e-02
}

colors = ['red', 'green', 'blue', 'orange']

for i, (label, value) in enumerate(values.items()):
    ax.axhline(y=value, color=colors[i], linestyle='--', label=label)

# Increase the size of text for various elements
plt.title('Comparison of Dorado and Guppy for Fast, Hac, and Sup for 8xA100', fontsize=16)  # Adjust the fontsize as needed
plt.ylabel('Gb/s', fontsize=12)  # Adjust the fontsize as needed
plt.ylim(top=0.06)  
# Rotate x-axis labels
plt.xticks(rotation=0, fontsize=12)  # Adjust the fontsize as needed

# Make legend smaller
ax.legend(fontsize='large', bbox_to_anchor=(1, 0.85)) 

plt.show()

# %%
# Transposing the DataFrame for easier plotting
df_4A100_T = df_4A100.set_index('Basecaller').T

# Enlarge the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plotting
ax = df_4A100_T.plot(kind='bar', width=0.7, ax=ax)

# Adding horizontal lines for the specified values in different colors
values = {
    'Promethion48_TMO': 5.37e-02,
    'Promethion48_keepup': 2.78e-02,
    'Promethion24_TMO': 2.69e-02,
    'Promethion24_keepup': 1.39e-02
}

colors = ['red', 'green', 'blue', 'orange']

for i, (label, value) in enumerate(values.items()):
    ax.axhline(y=value, color=colors[i], linestyle='--', label=label)

# Increase the size of text for various elements
plt.title('Comparison of Dorado and Guppy for Fast, Hac, and Sup for 4xA100', fontsize=16)  # Adjust the fontsize as needed
plt.ylabel('Gb/s', fontsize=12)  # Adjust the fontsize as needed
plt.ylim(top=0.06)  
# Rotate x-axis labels
plt.xticks(rotation=0, fontsize=12)  # Adjust the fontsize as needed

# Make legend smaller
ax.legend(fontsize='large', bbox_to_anchor=(1, 0.85)) 

plt.show()

# %%
# Transposing the DataFrame for easier plotting
df_1V100_T = df_1V100.set_index('Basecaller').T

# Enlarge the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plotting
ax = df_1V100_T.plot(kind='bar', width=0.7, ax=ax)

# Adding horizontal lines for the specified values in different colors
values = {
    'Promethion48_TMO': 5.37e-02,
    'Promethion48_keepup': 2.78e-02,
    'Promethion24_TMO': 2.69e-02,
    'Promethion24_keepup': 1.39e-02
}

colors = ['red', 'green', 'blue', 'orange']

for i, (label, value) in enumerate(values.items()):
    ax.axhline(y=value, color=colors[i], linestyle='--', label=label)

# Increase the size of text for various elements
plt.title('Comparison of Dorado and Guppy for Fast, Hac, and Sup for 1xV100', fontsize=16)  # Adjust the fontsize as needed
plt.ylabel('Gb/s', fontsize=12)  # Adjust the fontsize as needed
plt.ylim(top=0.06)  
# Rotate x-axis labels
plt.xticks(rotation=0, fontsize=12)  # Adjust the fontsize as needed

# Make legend smaller
ax.legend(fontsize='large', bbox_to_anchor=(1, 0.85)) 

plt.show()

# %%
# Transposing the DataFrame for easier plotting
df_4V100_T = df_4V100.set_index('Basecaller').T

# Enlarge the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plotting
ax = df_4V100_T.plot(kind='bar', width=0.7, ax=ax)

# Adding horizontal lines for the specified values in different colors
values = {
    'Promethion48_TMO': 5.37e-02,
    'Promethion48_keepup': 2.78e-02,
    'Promethion24_TMO': 2.69e-02,
    'Promethion24_keepup': 1.39e-02
}

colors = ['red', 'green', 'blue', 'orange']

for i, (label, value) in enumerate(values.items()):
    ax.axhline(y=value, color=colors[i], linestyle='--', label=label)

# Increase the size of text for various elements
plt.title('Comparison of Dorado and Guppy for Fast, Hac, and Sup for 4xV100', fontsize=16)  # Adjust the fontsize as needed
plt.ylabel('Gb/s', fontsize=12)  # Adjust the fontsize as needed
plt.ylim(top=0.06)  
# Rotate x-axis labels
plt.xticks(rotation=0, fontsize=12)  # Adjust the fontsize as needed

# Make legend smaller
ax.legend(fontsize='large', bbox_to_anchor=(1, 0.85)) 

plt.show()
